# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresJaquez128/-EPPL-Area-de-un-triangulo-mis-imagenes/blob/main/uii_act_11_df___codigo_python_jaquez_andres_0074.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Jaquez Andres NL = 27 Fecha = 25/Mar/2026 👾
# ---
# # Calcular Area de un Triangulo
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/AndresJaquez128/-EPPL-Area-de-un-triangulo-mis-imagenes/refs/heads/main/El_Area_triangulo.png)
#
# ---
# ## formula para calcular area
# A = bxh/2
#
# ---
# ## Diagrama de flujo en Lucidchart
# ![Logo de Markdown](https://raw.githubusercontent.com/AndresJaquez128/-EPPL-Area-de-un-triangulo-mis-imagenes/refs/heads/main/DF_area_triangulo.png)

# %%
# Calcular area del Triangulo
# Obtener altura y guardarla en variable H
# Obtener Base y guardarla en B
# Obtener area con la formula A = (B*A)/2
print("programa para calcular el area de un triangulo")
A = float(input("ingrese la altura del triangulo: "))
B = float(input("ingrese la base del triangulo: "))
Area = (B*A)/2
print("el area del triangulo es: ", Area)
print("Programa realizado por Jaquez Andres NL = 27")
# Out:
# programa para calcular el area de un triangulo
# ingrese la altura del triangulo: 7
# ingrese la base del triangulo: 4
# el area del triangulo es:  14.0
# Programa realizado por Jaquez Andres NL = 27

# %% [markdown]
# # Comparacion de codigo y DF Tldraw
# ![Logo de Markdown](https://raw.githubusercontent.com/AndresJaquez128/-EPPL-Area-de-un-triangulo-mis-imagenes/refs/heads/main/Area_TrianguloRectangulo.png)
